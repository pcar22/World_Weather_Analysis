# %% [markdown]
# ### Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.

import pandas as pd
import numpy as np
import requests

from citipy import citipy
from config import weather_api_key
from pprint import pprint
import json

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
cities = list()

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

        # Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])

# %%
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Perform an API call with the OpenWeatherMap.#5
record_count = 1 
set_count = 1

city_data = list()
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
# print(json.dumps(response, indent=4, sort_keys=True))

# %%
import time
from datetime import datetime

# %%
# Retrieve the following information from the API call: lat/lng, max temp, percent humidity, percent cloudiness, wind speed,
# weather decsription (for example, clouds, fog, light rain, clear sky)

record_count = 1
set_count = 1

# Loop through all the cities in our list.
# for i in range(len(cities)): New line below instead of this line.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | blind river
# Processing Record 2 of Set 1 | auki
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | kalulushi
# Processing Record 5 of Set 1 | bambous virieux
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | khatanga
# Processing Record 9 of Set 1 | balykshi
# Processing Record 10 of Set 1 | shimoda
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | jackson
# Processing Record 13 of Set 1 | guerrero negro
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | hasaki
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | zwedru
# Processing Record 19 of Set 1 | beringovskiy
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | slave lake
# Processing Record 23 of Set 1 | tabuk
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | kokkinion
# City not found. Skipping...
# Processing Record 26 of Set 1 | tytuvenai
# Processing Record 27 of Set 1 | harnosand
# Processing Record 28 of Set 1 | wajir
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | palmer
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | victor harbor
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | padang
# Processing Record 41 of Set 1 | sangar
# Processing Record 42 of Set 1 | esso
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | lasa
# Processing Record 47 of Set 1 | iquitos
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | port lincoln
# Processing Record 5 of Set 2 | tigzirt
# Processing Record 6 of Set 2 | macau
# Processing Record 7 of Set 2 | riyadh
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | havelock
# Processing Record 11 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | elizabeth city
# Processing Record 14 of Set 2 | liaocheng
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | saint george
# Processing Record 17 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 2 | aswan
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | vardo
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | jablah
# Processing Record 25 of Set 2 | xining
# Processing Record 26 of Set 2 | cockburn town
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | ixtapa
# Processing Record 29 of Set 2 | zhuhai
# Processing Record 30 of Set 2 | vaini
# Processing Record 31 of Set 2 | sao joao da barra
# Processing Record 32 of Set 2 | proletariy
# Processing Record 33 of Set 2 | les cayes
# Processing Record 34 of Set 2 | pangnirtung
# Processing Record 35 of Set 2 | sinnamary
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | kapaa
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | san quintin
# Processing Record 40 of Set 2 | yulara
# Processing Record 41 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 2 | los llanos de aridane
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | puerto ayora
# Processing Record 48 of Set 2 | neuquen
# Processing Record 49 of Set 2 | inhambane
# Processing Record 50 of Set 2 | camacha
# Processing Record 1 of Set 3 | omsukchan
# Processing Record 2 of Set 3 | suhbaatar
# Processing Record 3 of Set 3 | poronaysk
# Processing Record 4 of Set 3 | minab
# Processing Record 5 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 3 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 8 of Set 3 | lavrentiya
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | norman wells
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | korla
# Processing Record 13 of Set 3 | yingcheng
# Processing Record 14 of Set 3 | san carlos de bariloche
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | asfi
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | sirpur
# Processing Record 19 of Set 3 | goderich
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | cherskiy
# Processing Record 22 of Set 3 | socorro
# Processing Record 23 of Set 3 | noumea
# Processing Record 24 of Set 3 | airai
# Processing Record 25 of Set 3 | chapais
# Processing Record 26 of Set 3 | kulhudhuffushi
# Processing Record 27 of Set 3 | calbiga
# Processing Record 28 of Set 3 | providencia
# Processing Record 29 of Set 3 | asau
# Processing Record 30 of Set 3 | college
# Processing Record 31 of Set 3 | butaritari
# Processing Record 32 of Set 3 | coahuayana
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | miquelon
# Processing Record 35 of Set 3 | ust-ilimsk
# Processing Record 36 of Set 3 | severo-yeniseyskiy
# Processing Record 37 of Set 3 | khuzhir
# Processing Record 38 of Set 3 | najran
# Processing Record 39 of Set 3 | tuatapere
# Processing Record 40 of Set 3 | taksimo
# Processing Record 41 of Set 3 | havoysund
# Processing Record 42 of Set 3 | arcachon
# Processing Record 43 of Set 3 | shirokiy
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | kerouane
# Processing Record 46 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 3 | corrooy
# Processing Record 48 of Set 3 | liverpool
# Processing Record 49 of Set 3 | lebu
# Processing Record 50 of Set 3 | berlevag
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | mao
# Processing Record 3 of Set 4 | kaithal
# Processing Record 4 of Set 4 | acapulco
# Processing Record 5 of Set 4 | bengkulu
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | fairbanks
# Processing Record 8 of Set 4 | constitucion
# Processing Record 9 of Set 4 | tawzar
# City not found. Skipping...
# Processing Record 10 of Set 4 | amapa
# Processing Record 11 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 12 of Set 4 | evensk
# Processing Record 13 of Set 4 | xuddur
# Processing Record 14 of Set 4 | clyde river
# Processing Record 15 of Set 4 | hami
# Processing Record 16 of Set 4 | kamenka
# Processing Record 17 of Set 4 | longyearbyen
# Processing Record 18 of Set 4 | huarmey
# Processing Record 19 of Set 4 | cochrane
# Processing Record 20 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 4 | tabatinga
# Processing Record 22 of Set 4 | fallon
# Processing Record 23 of Set 4 | coquimbo
# Processing Record 24 of Set 4 | nizhniy tsasuchey
# Processing Record 25 of Set 4 | zhangjiakou
# Processing Record 26 of Set 4 | bilma
# Processing Record 27 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 28 of Set 4 | mahebourg
# Processing Record 29 of Set 4 | geraldton
# Processing Record 30 of Set 4 | kodiak
# Processing Record 31 of Set 4 | mana
# Processing Record 32 of Set 4 | kushima
# Processing Record 33 of Set 4 | san luis
# Processing Record 34 of Set 4 | kiunga
# Processing Record 35 of Set 4 | tuktoyaktuk
# Processing Record 36 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 37 of Set 4 | peniche
# Processing Record 38 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 4 | velizh
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | musoma
# Processing Record 42 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | vao
# Processing Record 44 of Set 4 | mehamn
# Processing Record 45 of Set 4 | cap malheureux
# Processing Record 46 of Set 4 | svetlogorsk
# Processing Record 47 of Set 4 | upata
# Processing Record 48 of Set 4 | shenkursk
# Processing Record 49 of Set 4 | arlit
# Processing Record 50 of Set 4 | zambezi
# Processing Record 1 of Set 5 | ulladulla
# Processing Record 2 of Set 5 | tiksi
# Processing Record 3 of Set 5 | manavalakurichi
# Processing Record 4 of Set 5 | bosaso
# Processing Record 5 of Set 5 | lompoc
# Processing Record 6 of Set 5 | sao felix do xingu
# Processing Record 7 of Set 5 | winslow
# Processing Record 8 of Set 5 | alice springs
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | luanda
# Processing Record 11 of Set 5 | saint-philippe
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | avera
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | lakes entrance
# Processing Record 17 of Set 5 | nanortalik
# Processing Record 18 of Set 5 | hinatuan
# Processing Record 19 of Set 5 | tamalin
# Processing Record 20 of Set 5 | nelson bay
# Processing Record 21 of Set 5 | san cristobal
# Processing Record 22 of Set 5 | ribeira grande
# Processing Record 23 of Set 5 | komsomolskiy
# Processing Record 24 of Set 5 | mokrousovo
# Processing Record 25 of Set 5 | jeremie
# Processing Record 26 of Set 5 | novikovo
# Processing Record 27 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 28 of Set 5 | sao filipe
# Processing Record 29 of Set 5 | ondjiva
# Processing Record 30 of Set 5 | manokwari
# Processing Record 31 of Set 5 | krasnyy yar
# Processing Record 32 of Set 5 | bam
# Processing Record 33 of Set 5 | solhan
# Processing Record 34 of Set 5 | lagoa
# Processing Record 35 of Set 5 | hithadhoo
# Processing Record 36 of Set 5 | buraydah
# Processing Record 37 of Set 5 | esik
# Processing Record 38 of Set 5 | la asuncion
# Processing Record 39 of Set 5 | vostok
# Processing Record 40 of Set 5 | kathu
# Processing Record 41 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 5 | radstadt
# Processing Record 43 of Set 5 | biak
# Processing Record 44 of Set 5 | zyryanka
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | zhanaozen
# Processing Record 48 of Set 5 | ostrovnoy
# Processing Record 49 of Set 5 | milton
# Processing Record 50 of Set 5 | clacton-on-sea
# Processing Record 1 of Set 6 | villa carlos paz
# Processing Record 2 of Set 6 | clarence town
# Processing Record 3 of Set 6 | chuy
# Processing Record 4 of Set 6 | zaltan
# Processing Record 5 of Set 6 | samarai
# Processing Record 6 of Set 6 | antofagasta
# Processing Record 7 of Set 6 | vila franca do campo
# Processing Record 8 of Set 6 | sola
# Processing Record 9 of Set 6 | pokosnoye
# Processing Record 10 of Set 6 | la palma
# Processing Record 11 of Set 6 | marzuq
# Processing Record 12 of Set 6 | kilindoni
# Processing Record 13 of Set 6 | vychegodskiy
# Processing Record 14 of Set 6 | hervey bay
# Processing Record 15 of Set 6 | kavieng
# Processing Record 16 of Set 6 | storsteinnes
# Processing Record 17 of Set 6 | alexandria
# Processing Record 18 of Set 6 | katsuura
# Processing Record 19 of Set 6 | kollo
# Processing Record 20 of Set 6 | camana
# Processing Record 21 of Set 6 | hambantota
# Processing Record 22 of Set 6 | tawang
# Processing Record 23 of Set 6 | kununurra
# Processing Record 24 of Set 6 | kahului
# Processing Record 25 of Set 6 | junin
# Processing Record 26 of Set 6 | anadyr
# Processing Record 27 of Set 6 | bobrovytsya
# Processing Record 28 of Set 6 | kemijarvi
# Processing Record 29 of Set 6 | pentecoste
# Processing Record 30 of Set 6 | arkadelphia
# Processing Record 31 of Set 6 | yanam
# Processing Record 32 of Set 6 | abu zabad
# Processing Record 33 of Set 6 | sai buri
# Processing Record 34 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 6 | saint anthony
# Processing Record 36 of Set 6 | zhigansk
# Processing Record 37 of Set 6 | kysyl-syr
# Processing Record 38 of Set 6 | kungsbacka
# Processing Record 39 of Set 6 | quatre cocos
# Processing Record 40 of Set 6 | achalpur
# Processing Record 41 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 42 of Set 6 | sinop
# Processing Record 43 of Set 6 | gat
# Processing Record 44 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 6 | salalah
# Processing Record 46 of Set 6 | la rioja
# Processing Record 47 of Set 6 | hay river
# Processing Record 48 of Set 6 | broken hill
# Processing Record 49 of Set 6 | perbaungan
# Processing Record 50 of Set 6 | yumen
# Processing Record 1 of Set 7 | tessalit
# Processing Record 2 of Set 7 | mackenzie
# Processing Record 3 of Set 7 | santa maria
# Processing Record 4 of Set 7 | gizo
# Processing Record 5 of Set 7 | kirakira
# Processing Record 6 of Set 7 | mersing
# Processing Record 7 of Set 7 | hamilton
# Processing Record 8 of Set 7 | leh
# Processing Record 9 of Set 7 | shingu
# Processing Record 10 of Set 7 | sabinopolis
# Processing Record 11 of Set 7 | anar darreh
# City not found. Skipping...
# Processing Record 12 of Set 7 | nurota
# Processing Record 13 of Set 7 | pevek
# Processing Record 14 of Set 7 | hilo
# Processing Record 15 of Set 7 | la ronge
# Processing Record 16 of Set 7 | ballina
# Processing Record 17 of Set 7 | beidao
# Processing Record 18 of Set 7 | manyana
# Processing Record 19 of Set 7 | agadez
# Processing Record 20 of Set 7 | kachiry
# Processing Record 21 of Set 7 | narsaq
# Processing Record 22 of Set 7 | mitsamiouli
# Processing Record 23 of Set 7 | diffa
# Processing Record 24 of Set 7 | talara
# Processing Record 25 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 7 | sibolga
# Processing Record 27 of Set 7 | homer
# Processing Record 28 of Set 7 | atar
# Processing Record 29 of Set 7 | salinopolis
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | tsagan aman
# Processing Record 32 of Set 7 | saint-leu
# Processing Record 33 of Set 7 | portland
# Processing Record 34 of Set 7 | marrakesh
# Processing Record 35 of Set 7 | artesia
# Processing Record 36 of Set 7 | conakry
# Processing Record 37 of Set 7 | fayetteville
# Processing Record 38 of Set 7 | puerto ayacucho
# Processing Record 39 of Set 7 | hovd
# Processing Record 40 of Set 7 | dauphin
# Processing Record 41 of Set 7 | pastavy
# Processing Record 42 of Set 7 | villiers
# Processing Record 43 of Set 7 | a
# City not found. Skipping...
# Processing Record 44 of Set 7 | sisimiut
# Processing Record 45 of Set 7 | cavalcante
# Processing Record 46 of Set 7 | mount darwin
# Processing Record 47 of Set 7 | gillette
# Processing Record 48 of Set 7 | ambon
# Processing Record 49 of Set 7 | bantou
# Processing Record 50 of Set 7 | mpulungu
# Processing Record 1 of Set 8 | llata
# Processing Record 2 of Set 8 | kudahuvadhoo
# Processing Record 3 of Set 8 | padilla
# Processing Record 4 of Set 8 | anloga
# Processing Record 5 of Set 8 | port hardy
# Processing Record 6 of Set 8 | bata
# Processing Record 7 of Set 8 | great yarmouth
# Processing Record 8 of Set 8 | iqaluit
# Processing Record 9 of Set 8 | bandundu
# Processing Record 10 of Set 8 | sur
# Processing Record 11 of Set 8 | honningsvag
# Processing Record 12 of Set 8 | comodoro rivadavia
# Processing Record 13 of Set 8 | rawson
# Processing Record 14 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 8 | jiujiang
# Processing Record 16 of Set 8 | north bend
# Processing Record 17 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 18 of Set 8 | altay
# Processing Record 19 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 20 of Set 8 | leshukonskoye
# Processing Record 21 of Set 8 | shelburne
# Processing Record 22 of Set 8 | barabinsk
# Processing Record 23 of Set 8 | souillac
# Processing Record 24 of Set 8 | klaksvik
# Processing Record 25 of Set 8 | merke
# Processing Record 26 of Set 8 | sitka
# Processing Record 27 of Set 8 | lichinga
# Processing Record 28 of Set 8 | deputatskiy
# Processing Record 29 of Set 8 | tabarqah
# City not found. Skipping...
# Processing Record 30 of Set 8 | diamantino
# Processing Record 31 of Set 8 | borujan
# City not found. Skipping...
# Processing Record 32 of Set 8 | panjab
# Processing Record 33 of Set 8 | praia
# Processing Record 34 of Set 8 | lashio
# Processing Record 35 of Set 8 | hinton
# Processing Record 36 of Set 8 | itanagar
# Processing Record 37 of Set 8 | namie
# Processing Record 38 of Set 8 | newport
# Processing Record 39 of Set 8 | makakilo city
# Processing Record 40 of Set 8 | marsh harbour
# Processing Record 41 of Set 8 | norrtalje
# Processing Record 42 of Set 8 | komsomolets
# Processing Record 43 of Set 8 | sperkhias
# City not found. Skipping...
# Processing Record 44 of Set 8 | praia da vitoria
# Processing Record 45 of Set 8 | port-de-bouc
# Processing Record 46 of Set 8 | hobyo
# Processing Record 47 of Set 8 | johnstown
# Processing Record 48 of Set 8 | faya
# Processing Record 49 of Set 8 | gibsons
# Processing Record 50 of Set 8 | zaozhuang
# Processing Record 1 of Set 9 | baculin
# Processing Record 2 of Set 9 | egvekinot
# Processing Record 3 of Set 9 | almaznyy
# Processing Record 4 of Set 9 | shahrud
# Processing Record 5 of Set 9 | joutseno
# Processing Record 6 of Set 9 | uglegorsk
# Processing Record 7 of Set 9 | baykit
# Processing Record 8 of Set 9 | pau
# Processing Record 9 of Set 9 | codrington
# Processing Record 10 of Set 9 | utena
# Processing Record 11 of Set 9 | durban
# Processing Record 12 of Set 9 | shenjiamen
# Processing Record 13 of Set 9 | ndele
# Processing Record 14 of Set 9 | bootle
# Processing Record 15 of Set 9 | edgecumbe
# Processing Record 16 of Set 9 | presidente medici
# Processing Record 17 of Set 9 | neyshabur
# Processing Record 18 of Set 9 | kieta
# Processing Record 19 of Set 9 | bilibino
# Processing Record 20 of Set 9 | namatanai
# Processing Record 21 of Set 9 | dubna
# Processing Record 22 of Set 9 | seddon
# Processing Record 23 of Set 9 | escanaba
# Processing Record 24 of Set 9 | general pico
# Processing Record 25 of Set 9 | quirinopolis
# Processing Record 26 of Set 9 | creel
# Processing Record 27 of Set 9 | caxito
# Processing Record 28 of Set 9 | stephenville crossing
# Processing Record 29 of Set 9 | traverse city
# Processing Record 30 of Set 9 | ilulissat
# Processing Record 31 of Set 9 | san andres
# Processing Record 32 of Set 9 | udachnyy
# Processing Record 33 of Set 9 | tocopilla
# Processing Record 34 of Set 9 | wonthaggi
# Processing Record 35 of Set 9 | grand-santi
# Processing Record 36 of Set 9 | grindavik
# Processing Record 37 of Set 9 | dzerzhinsk
# Processing Record 38 of Set 9 | maarianhamina
# Processing Record 39 of Set 9 | myingyan
# Processing Record 40 of Set 9 | kumbo
# Processing Record 41 of Set 9 | gornyy
# Processing Record 42 of Set 9 | todos santos
# Processing Record 43 of Set 9 | nepa nagar
# Processing Record 44 of Set 9 | shurugwi
# Processing Record 45 of Set 9 | faro
# Processing Record 46 of Set 9 | isangel
# Processing Record 47 of Set 9 | honiara
# Processing Record 48 of Set 9 | dubasari
# Processing Record 49 of Set 9 | skelleftea
# Processing Record 50 of Set 9 | dumai
# Processing Record 1 of Set 10 | noyabrsk
# Processing Record 2 of Set 10 | pavino
# Processing Record 3 of Set 10 | jardim
# Processing Record 4 of Set 10 | turan
# Processing Record 5 of Set 10 | tazmalt
# Processing Record 6 of Set 10 | nadapuram
# Processing Record 7 of Set 10 | cedar city
# Processing Record 8 of Set 10 | ust-nera
# Processing Record 9 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 10 | black forest
# Processing Record 11 of Set 10 | umea
# Processing Record 12 of Set 10 | ambilobe
# Processing Record 13 of Set 10 | cayenne
# Processing Record 14 of Set 10 | camocim
# Processing Record 15 of Set 10 | havre-saint-pierre
# Processing Record 16 of Set 10 | crestview
# Processing Record 17 of Set 10 | siniscola
# Processing Record 18 of Set 10 | mildura
# Processing Record 19 of Set 10 | san vicente
# Processing Record 20 of Set 10 | garoua boulai
# Processing Record 21 of Set 10 | lata
# Processing Record 22 of Set 10 | salina cruz
# Processing Record 23 of Set 10 | ketchikan
# Processing Record 24 of Set 10 | pisticci
# Processing Record 25 of Set 10 | yar-sale
# Processing Record 26 of Set 10 | te anau
# Processing Record 27 of Set 10 | rio gallegos
# Processing Record 28 of Set 10 | tiarei
# Processing Record 29 of Set 10 | saldanha
# Processing Record 30 of Set 10 | plettenberg bay
# Processing Record 31 of Set 10 | mogadishu
# Processing Record 32 of Set 10 | tumpat
# Processing Record 33 of Set 10 | verkhniy lomov
# Processing Record 34 of Set 10 | paita
# Processing Record 35 of Set 10 | katherine
# Processing Record 36 of Set 10 | el retorno
# Processing Record 37 of Set 10 | zanjan
# Processing Record 38 of Set 10 | ylivieska
# Processing Record 39 of Set 10 | port-gentil
# Processing Record 40 of Set 10 | frederico westphalen
# Processing Record 41 of Set 10 | lorengau
# Processing Record 42 of Set 10 | mount isa
# Processing Record 43 of Set 10 | tonekabon
# Processing Record 44 of Set 10 | rutul
# Processing Record 45 of Set 10 | nago
# Processing Record 46 of Set 10 | cabo san lucas
# Processing Record 47 of Set 10 | hazorasp
# Processing Record 48 of Set 10 | gondanglegi
# Processing Record 49 of Set 10 | muana
# Processing Record 50 of Set 10 | higueron
# Processing Record 1 of Set 11 | quelimane
# Processing Record 2 of Set 11 | toungoo
# City not found. Skipping...
# Processing Record 3 of Set 11 | grand-lahou
# Processing Record 4 of Set 11 | kenai
# Processing Record 5 of Set 11 | mattru
# Processing Record 6 of Set 11 | maiduguri
# Processing Record 7 of Set 11 | magdagachi
# Processing Record 8 of Set 11 | dassel
# Processing Record 9 of Set 11 | port macquarie
# Processing Record 10 of Set 11 | laguna
# Processing Record 11 of Set 11 | nouadhibou
# Processing Record 12 of Set 11 | marathon
# Processing Record 13 of Set 11 | maceio
# Processing Record 14 of Set 11 | hirara
# Processing Record 15 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 11 | huangmei
# Processing Record 17 of Set 11 | kavaratti
# Processing Record 18 of Set 11 | mount gambier
# Processing Record 19 of Set 11 | loukhi
# Processing Record 20 of Set 11 | kutum
# Processing Record 21 of Set 11 | alofi
# Processing Record 22 of Set 11 | nakatunguru
# Processing Record 23 of Set 11 | la orilla
# Processing Record 24 of Set 11 | atambua
# Processing Record 25 of Set 11 | sukhumi
# Processing Record 26 of Set 11 | uruacu
# Processing Record 27 of Set 11 | balkanabat
# Processing Record 28 of Set 11 | gunnedah
# Processing Record 29 of Set 11 | syamzha
# Processing Record 30 of Set 11 | boende
# Processing Record 31 of Set 11 | namibe
# Processing Record 32 of Set 11 | chabahar
# Processing Record 33 of Set 11 | krasnoselkup
# Processing Record 34 of Set 11 | savinka
# Processing Record 35 of Set 11 | san patricio
# Processing Record 36 of Set 11 | toora-khem
# Processing Record 37 of Set 11 | imbituba
# Processing Record 38 of Set 11 | stornoway
# Processing Record 39 of Set 11 | itoman
# Processing Record 40 of Set 11 | burica
# City not found. Skipping...
# Processing Record 41 of Set 11 | valparaiso
# Processing Record 42 of Set 11 | ninotsminda
# Processing Record 43 of Set 11 | santa ana
# Processing Record 44 of Set 11 | det udom
# Processing Record 45 of Set 11 | koumac
# Processing Record 46 of Set 11 | taonan
# Processing Record 47 of Set 11 | coalcoman
# City not found. Skipping...
# Processing Record 48 of Set 11 | andenes
# Processing Record 49 of Set 11 | cranbrook
# Processing Record 50 of Set 11 | matagami
# Processing Record 1 of Set 12 | sao miguel do araguaia
# Processing Record 2 of Set 12 | borisoglebsk
# Processing Record 3 of Set 12 | skibbereen
# Processing Record 4 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 12 | tallahassee
# Processing Record 7 of Set 12 | tuy hoa
# Processing Record 8 of Set 12 | whitecourt
# Processing Record 9 of Set 12 | billings
# Processing Record 10 of Set 12 | mpophomeni
# Processing Record 11 of Set 12 | flin flon
# Processing Record 12 of Set 12 | husavik
# Processing Record 13 of Set 12 | dibaya
# City not found. Skipping...
# Processing Record 14 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 12 | fuerte olimpo
# Processing Record 16 of Set 12 | bhag
# Processing Record 17 of Set 12 | bodden town
# Processing Record 18 of Set 12 | muzquiz
# City not found. Skipping...
# Processing Record 19 of Set 12 | mackay
# Processing Record 20 of Set 12 | saiha
# Processing Record 21 of Set 12 | yeniseysk
# Processing Record 22 of Set 12 | kurchum
# Processing Record 23 of Set 12 | turayf
# Processing Record 24 of Set 12 | caravelas
# Processing Record 25 of Set 12 | dungarvan
# Processing Record 26 of Set 12 | lanigan
# Processing Record 27 of Set 12 | palaikastron
# Processing Record 28 of Set 12 | ahipara
# Processing Record 29 of Set 12 | hanyang
# Processing Record 30 of Set 12 | punta cardon
# Processing Record 31 of Set 12 | mocuba
# Processing Record 32 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 12 | houston
# Processing Record 34 of Set 12 | wasilla
# Processing Record 35 of Set 12 | susanino
# Processing Record 36 of Set 12 | malanje
# Processing Record 37 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 12 | waipawa
# Processing Record 39 of Set 12 | eureka
# Processing Record 40 of Set 12 | banff
# Processing Record 41 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 43 of Set 12 | rocha
# Processing Record 44 of Set 12 | ippy
# Processing Record 45 of Set 12 | sambava
# Processing Record 46 of Set 12 | staritsa
# Processing Record 47 of Set 12 | kailua
# Processing Record 48 of Set 12 | hailey
# Processing Record 49 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 50 of Set 12 | skjervoy
# Processing Record 1 of Set 13 | pathein
# Processing Record 2 of Set 13 | yunyang
# Processing Record 3 of Set 13 | keffi
# Processing Record 4 of Set 13 | gilgit
# Processing Record 5 of Set 13 | twentynine palms
# Processing Record 6 of Set 13 | ialibu
# Processing Record 7 of Set 13 | byron bay
# Processing Record 8 of Set 13 | falakata
# Processing Record 9 of Set 13 | ranong
# Processing Record 10 of Set 13 | taunggyi
# Processing Record 11 of Set 13 | vestmannaeyjar
# Processing Record 12 of Set 13 | siavonga
# Processing Record 13 of Set 13 | chirilagua
# Processing Record 14 of Set 13 | leningradskiy
# Processing Record 15 of Set 13 | zilupe
# Processing Record 16 of Set 13 | dolzhanskaya
# Processing Record 17 of Set 13 | puerto leguizamo
# Processing Record 18 of Set 13 | richards bay
# Processing Record 19 of Set 13 | pagsangahan
# Processing Record 20 of Set 13 | mahajanga
# Processing Record 21 of Set 13 | soyo
# Processing Record 22 of Set 13 | otradnoye
# Processing Record 23 of Set 13 | bunbury
# Processing Record 24 of Set 13 | lucea
# Processing Record 25 of Set 13 | taltal
# Processing Record 26 of Set 13 | srednekolymsk
# Processing Record 27 of Set 13 | urucui
# Processing Record 28 of Set 13 | nanticoke
# Processing Record 29 of Set 13 | yenangyaung
# Processing Record 30 of Set 13 | zabaykalsk
# Processing Record 31 of Set 13 | ortona
# Processing Record 32 of Set 13 | jinchang
# Processing Record 33 of Set 13 | ha
# City not found. Skipping...
# Processing Record 34 of Set 13 | ladario
# Processing Record 35 of Set 13 | niltepec
# Processing Record 36 of Set 13 | touros
# Processing Record 37 of Set 13 | akdepe
# Processing Record 38 of Set 13 | ostersund
# Processing Record 39 of Set 13 | senador jose porfirio
# Processing Record 40 of Set 13 | sembe
# Processing Record 41 of Set 13 | sabha
# Processing Record 42 of Set 13 | beipiao
# Processing Record 43 of Set 13 | bacalar
# Processing Record 44 of Set 13 | cefalu
# Processing Record 45 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 13 | puerto escondido
# Processing Record 47 of Set 13 | natal
# Processing Record 48 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 13 | norwich
# Processing Record 50 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 1 of Set 14 | solnechnyy
# Processing Record 2 of Set 14 | rapid valley
# Processing Record 3 of Set 14 | juneau
# Processing Record 4 of Set 14 | roebourne
# Processing Record 5 of Set 14 | cozumel
# Processing Record 6 of Set 14 | karratha
# Processing Record 7 of Set 14 | dunedin
# Processing Record 8 of Set 14 | alibag
# Processing Record 9 of Set 14 | matara
# Processing Record 10 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 14 | wamba
# Processing Record 12 of Set 14 | bom jesus da lapa
# Processing Record 13 of Set 14 | carlsbad
# Processing Record 14 of Set 14 | jinxiang
# Processing Record 15 of Set 14 | santa rosa
# Processing Record 16 of Set 14 | ribas do rio pardo
# Processing Record 17 of Set 14 | hofn
# Processing Record 18 of Set 14 | olginskaya
# Processing Record 19 of Set 14 | waingapu
# Processing Record 20 of Set 14 | ligayan
# Processing Record 21 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 14 | we
# City not found. Skipping...
# Processing Record 24 of Set 14 | rudnogorsk
# Processing Record 25 of Set 14 | guasdualito
# Processing Record 26 of Set 14 | oranjemund
# Processing Record 27 of Set 14 | fergus falls
# Processing Record 28 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 29 of Set 14 | yanliang
# Processing Record 30 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 14 | luwuk
# Processing Record 32 of Set 14 | tura
# Processing Record 33 of Set 14 | yaan
# Processing Record 34 of Set 14 | makaha
# Processing Record 35 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 36 of Set 14 | kjopsvik
# Processing Record 37 of Set 14 | cordele
# Processing Record 38 of Set 14 | kargopol
# Processing Record 39 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 40 of Set 14 | labuhan
# Processing Record 41 of Set 14 | ayan
# Processing Record 42 of Set 14 | soria
# Processing Record 43 of Set 14 | maniitsoq
# Processing Record 44 of Set 14 | bagdarin
# Processing Record 45 of Set 14 | kyzyl-suu
# Processing Record 46 of Set 14 | iskateley
# Processing Record 47 of Set 14 | matay
# Processing Record 48 of Set 14 | yaitepec
# City not found. Skipping...
# Processing Record 49 of Set 14 | shiraz
# Processing Record 50 of Set 14 | sal rei
# Processing Record 1 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 15 | humberto de campos
# Processing Record 3 of Set 15 | olafsvik
# Processing Record 4 of Set 15 | andros town
# Processing Record 5 of Set 15 | libertador general san martin
# Processing Record 6 of Set 15 | naryan-mar
# Processing Record 7 of Set 15 | estaimpuis
# Processing Record 8 of Set 15 | taos
# Processing Record 9 of Set 15 | kouqian
# Processing Record 10 of Set 15 | tigil
# Processing Record 11 of Set 15 | aklavik
# Processing Record 12 of Set 15 | the pas
# Processing Record 13 of Set 15 | erenhot
# Processing Record 14 of Set 15 | necochea
# Processing Record 15 of Set 15 | port keats
# Processing Record 16 of Set 15 | tazovskiy
# Processing Record 17 of Set 15 | cartagena del chaira
# Processing Record 18 of Set 15 | baruun-urt
# Processing Record 19 of Set 15 | kloulklubed
# Processing Record 20 of Set 15 | caucaia
# Processing Record 21 of Set 15 | invermere
# Processing Record 22 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 24 of Set 15 | vallenar
# Processing Record 25 of Set 15 | karimpur
# Processing Record 26 of Set 15 | narasannapeta
# Processing Record 27 of Set 15 | yining
# Processing Record 28 of Set 15 | chesterville
# Processing Record 29 of Set 15 | dharchula
# Processing Record 30 of Set 15 | jining
# Processing Record 31 of Set 15 | gloversville
# Processing Record 32 of Set 15 | grand gaube
# Processing Record 33 of Set 15 | celestun
# Processing Record 34 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 15 | hualmay
# Processing Record 36 of Set 15 | awbari
# Processing Record 37 of Set 15 | iskilip
# Processing Record 38 of Set 15 | vaitape
# Processing Record 39 of Set 15 | viedma
# Processing Record 40 of Set 15 | benguela
# Processing Record 41 of Set 15 | meulaboh
# Processing Record 42 of Set 15 | alta floresta
# Processing Record 43 of Set 15 | capinopolis
# Processing Record 44 of Set 15 | novyy urengoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Blind River  46.1834  -82.9582     86.11        48          97
# 1             Auki  -8.7676  160.7034     81.54        74          13
# 2     Punta Arenas -53.1500  -70.9167     35.71        69           0
# 3        Kalulushi -12.8378   28.0919     56.26        65          12
# 4  Bambous Virieux -20.3428   57.7575     70.21        83          40
# 5     Ponta Do Sol  32.6667  -17.1000     73.13        70           2
# 6         Khatanga  71.9667  102.5000     52.65        81          10
# 7         Balykshi  47.0667   51.8667     71.60        83          40
# 8          Shimoda  34.6667  138.9500     80.10        78         100
# 9        Busselton -33.6500  115.3333     51.24        68          84
#
#    Wind Speed Country Current Description
# 0        6.53      CA     overcast clouds
# 1        2.93      SB          few clouds
# 2        9.22      CL           clear sky
# 3        4.32      ZM          few clouds
# 4       12.66      MU    scattered clouds
# 5        3.74      PT           clear sky
# 6       13.56      RU           clear sky
# 7        8.95      KZ                mist
# 8        6.15      JP     overcast clouds
# 9       13.02      AU       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Blind River      CA  46.1834  -82.9582     86.11        48          97
# 1             Auki      SB  -8.7676  160.7034     81.54        74          13
# 2     Punta Arenas      CL -53.1500  -70.9167     35.71        69           0
# 3        Kalulushi      ZM -12.8378   28.0919     56.26        65          12
# 4  Bambous Virieux      MU -20.3428   57.7575     70.21        83          40
# 5     Ponta Do Sol      PT  32.6667  -17.1000     73.13        70           2
# 6         Khatanga      RU  71.9667  102.5000     52.65        81          10
# 7         Balykshi      KZ  47.0667   51.8667     71.60        83          40
# 8          Shimoda      JP  34.6667  138.9500     80.10        78         100
# 9        Busselton      AU -33.6500  115.3333     51.24        68          84
#
#    Wind Speed Current Description
# 0        6.53     overcast clouds
# 1        2.93          few clouds
# 2        9.22           clear sky
# 3        4.32          few clouds
# 4       12.66    scattered clouds
# 5        3.74           clear sky
# 6       13.56           clear sky
# 7        8.95                mist
# 8        6.15     overcast clouds
# 9       13.02       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv" 
# Export CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
